# %%
import Matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
plt.figsize((10,6))
sns.hitsplot(df['price'],kde=True, color='skyblue')
plt.title('Distribution des Prix des Maisons')
plt.xlabel('Prix')
plt.ylabel('Fréquence')
plt.show()
